# %%
from scipy.io import wavfile
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from IPython.display import Audio
from python_speech_features import mfcc, fbank, logfbank

# %%
sr, wav = wavfile.read("../data/train/audio/yes/1a5b9ca4_nohash_0.wav")
plt.plot(wav)
Audio(wav, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(np.append(wav[0], wav[1:] - 0.97 * wav[:-1]))

# %%
_=plt.specgram(wav, Fs=sr)

# %%
features = mfcc(wav, samplerate=sr)
plt.imshow(features.T)

# %%
features = logfbank(wav, samplerate=sr)
plt.imshow(features.T)

# %%
sr, wav = wavfile.read("../data/train/audio/yes/00f0204f_nohash_1.wav")
plt.plot(wav)
Audio(wav, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
_=plt.specgram(wav, Fs=sr)

# %%
features = mfcc(wav, samplerate=sr)
plt.imshow(features.T)

# %%
features = logfbank(wav, samplerate=sr)
plt.imshow(features.T)
